# %%
import numpy as np
import pandas as pd
import os
from tvb.simulator.lab import models, connectivity, coupling, integrators, monitors, noise
from tvb.simulator.simulator import Simulator
# Out:
# /opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/datatypes/surfaces.py:60: UserWarning: Geodesic distance module is unavailable; some functionality for surfaces will be unavailable.
#   warnings.warn(msg)

# %%
np.random.seed(50)

# %%
def focal_dlpfc_lesion(conn, node_idx=18, weight_scale=0.8, tract_scale=1.2):
    W = conn.weights.copy()
    D = conn.tract_lengths.copy()
    W[node_idx, :] *= weight_scale
    W[:, node_idx] *= weight_scale
    D[node_idx, :] *= tract_scale
    D[:, node_idx] *= tract_scale
    conn_lesion = connectivity.Connectivity(weights=W, tract_lengths=D,
                           region_labels=conn.region_labels,
                           centres=conn.centres, speed=conn.speed.copy())
    conn_lesion.configure()
    return conn_lesion

# %%
def damp_node_dynamics(wc_model, node_idx=18, num_regions=76,
                       P_reduction=0.85, c_ie_increase=1.05):
    for pname in ('P', 'c_ie'):
        val = getattr(wc_model, pname)
        if val.size == 1:
            setattr(wc_model, pname, np.repeat(val[0], num_regions))
    wc_model.P[node_idx]    *= P_reduction
    wc_model.c_ie[node_idx] *= c_ie_increase

# %%
n_subjects = 50
results = []
output_dir = "tbi_mildgroup_results"
os.makedirs(output_dir, exist_ok=True)

# %%
for i in range(n_subjects):
    print(f"Running TBI subject {i+1}...")

    conn = connectivity.Connectivity.from_file("connectivity_76.zip")
    conn.configure()
    conn_lesion = focal_dlpfc_lesion(conn)

    wc = models.WilsonCowan(
        c_ee=np.array([np.random.normal(20.0, 1.0)]),
        c_ei=np.array([np.random.normal(12.0, 0.5)]),
        c_ie=np.array([np.random.normal(18.0, 1.0)]),
        c_ii=np.array([np.random.normal(3.0, 0.3)]),
        P=np.array([np.random.normal(0.45, 0.02)]),
        tau_e=np.array([10.0]),
        tau_i=np.array([25.0]),
    )
    damp_node_dynamics(wc, node_idx=18, num_regions=conn_lesion.number_of_regions)


    sim = Simulator(
        model=wc,
        connectivity=conn_lesion,  
        coupling=coupling.Scaling(a=np.array([0.003])),
        integrator=integrators.HeunDeterministic(dt=0.1),
        monitors=(monitors.Raw(variables_of_interest=np.array([0]), period=1.0),)
    )
    sim.simulation_length = 15000
    sim.configure()

    try:
        output = sim.run()[0]
        raw_data = output[1]
        print("Raw data shape before squeeze:", raw_data.shape)

        raw_data = np.squeeze(raw_data)
        print("Raw data shape after squeeze:", raw_data.shape)

        if raw_data.ndim == 2 and raw_data.shape[1] == conn_lesion.number_of_regions:
            ts = raw_data[:, 18]  
            alpha_power = np.mean(np.abs(np.fft.rfft(ts))**2)

            fc_matrix = np.corrcoef(raw_data.T)
            np.save(os.path.join(output_dir, f"fc_matrix_{i}.npy"), fc_matrix)
            mean_fc = np.mean(fc_matrix[np.triu_indices(fc_matrix.shape[0], k=1)])
        else:
            print(f"Unexpected shape for subject {i+1}. Skipping.")
            alpha_power = np.nan
            mean_fc = np.nan

    except Exception as e:
        print(f"Error for subject {i+1}: {e}")
        alpha_power = np.nan
        mean_fc = np.nan

    results.append({
        "subject_id": f"tbi_{i+1}",
        "alpha_power_dlpfc": alpha_power,
        "mean_fc_strength": mean_fc
    })
# Out:
# Running TBI subject 1...
# 2025-05-15 10:20:52,132 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:20:52,187 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:20:53,139 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 2...
# 2025-05-15 10:21:08,842 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:21:08,848 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:21:08,858 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 3...
# 2025-05-15 10:21:24,146 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:21:24,156 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:21:24,165 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 4...
# 2025-05-15 10:21:40,379 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:21:40,384 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:21:40,393 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 5...
# 2025-05-15 10:21:55,513 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:21:55,524 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:21:55,535 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 6...
# 2025-05-15 10:22:10,902 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:22:10,906 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:22:10,919 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 7...
# 2025-05-15 10:22:26,518 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:22:26,523 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:22:26,533 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 8...
# 2025-05-15 10:22:41,730 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:22:41,736 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:22:41,746 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 9...
# 2025-05-15 10:22:56,769 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:22:56,772 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:22:56,779 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 10...
# 2025-05-15 10:23:12,183 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:23:12,189 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:23:12,200 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 11...
# 2025-05-15 10:23:27,830 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:23:27,836 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:23:27,853 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 12...
# 2025-05-15 10:23:43,088 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:23:43,102 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:23:43,122 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 13...
# 2025-05-15 10:23:58,207 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:23:58,210 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:23:58,217 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 14...
# 2025-05-15 10:24:13,493 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:24:13,497 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:24:13,514 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 15...
# 2025-05-15 10:24:28,946 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:24:28,950 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:24:28,959 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 16...
# 2025-05-15 10:24:44,275 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:24:44,280 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:24:44,291 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 17...
# 2025-05-15 10:24:59,561 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:24:59,573 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:24:59,586 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 18...
# 2025-05-15 10:25:15,175 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:25:15,185 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:25:15,196 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 19...
# 2025-05-15 10:25:30,629 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:25:30,635 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:25:30,644 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 20...
# 2025-05-15 10:25:45,920 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:25:45,925 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:25:45,936 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 21...
# 2025-05-15 10:26:01,274 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:26:01,291 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:26:01,298 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 22...
# 2025-05-15 10:26:16,949 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:26:16,957 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:26:16,970 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 23...
# 2025-05-15 10:26:33,587 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:26:33,592 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:26:33,600 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 24...
# 2025-05-15 10:26:48,956 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:26:48,969 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:26:48,984 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 25...
# 2025-05-15 10:27:04,269 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:27:04,274 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:27:04,282 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 26...
# 2025-05-15 10:27:20,004 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:27:20,009 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:27:20,023 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 27...
# 2025-05-15 10:27:36,103 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:27:36,113 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:27:36,127 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 28...
# 2025-05-15 10:27:52,542 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:27:52,551 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:27:52,565 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 29...
# 2025-05-15 10:28:08,008 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:28:08,016 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:28:08,031 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 30...
# 2025-05-15 10:28:23,138 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:28:23,142 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:28:23,151 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 31...
# 2025-05-15 10:28:38,365 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:28:38,370 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:28:38,380 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 32...
# 2025-05-15 10:28:53,503 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:28:53,507 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:28:53,514 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 33...
# 2025-05-15 10:29:09,068 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:29:09,073 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:29:09,081 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 34...
# 2025-05-15 10:29:25,826 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:29:25,837 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:29:25,853 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 35...
# 2025-05-15 10:29:41,692 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
# ...
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:30:44,124 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:30:44,135 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 40...
# 2025-05-15 10:30:59,192 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:30:59,196 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:30:59,204 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 41...
# 2025-05-15 10:31:14,277 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:31:14,280 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:31:14,287 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 42...
# 2025-05-15 10:31:29,479 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:31:29,490 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:31:29,503 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 43...
# 2025-05-15 10:31:44,678 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:31:44,683 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:31:44,691 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 44...
# 2025-05-15 10:31:59,751 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:31:59,754 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:31:59,762 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 45...
# 2025-05-15 10:32:14,808 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:32:14,811 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:32:14,818 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 46...
# 2025-05-15 10:32:29,959 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:32:29,962 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:32:29,974 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 47...
# 2025-05-15 10:32:45,145 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:32:45,149 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:32:45,161 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 48...
# 2025-05-15 10:33:00,207 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:33:00,211 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:33:00,218 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 49...
# 2025-05-15 10:33:15,333 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:33:15,337 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:33:15,344 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)
# Running TBI subject 50...
# 2025-05-15 10:33:30,735 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:33:30,739 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:33:30,746 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape before squeeze: (150000, 1, 76, 1)
# Raw data shape after squeeze: (150000, 76)

# %%
df = pd.DataFrame(results)
df.to_csv(os.path.join(output_dir, "tbi_mild_group_metrics.csv"), index=False)
print("All TBI simulations completed. Results saved to:", output_dir)
# Out:
# All TBI simulations completed. Results saved to: tbi_mildgroup_results
