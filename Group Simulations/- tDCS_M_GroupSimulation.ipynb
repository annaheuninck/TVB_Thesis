# %%
import numpy as np
import pandas as pd
import os
import copy
from tvb.simulator.lab import models, connectivity, coupling, integrators, monitors
from tvb.simulator.simulator import Simulator
# Out:
# /opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/datatypes/surfaces.py:60: UserWarning: Geodesic distance module is unavailable; some functionality for surfaces will be unavailable.
#   warnings.warn(msg)

# %%
np.random.seed(50)

# %%
def focal_dlpfc_lesion(conn, node_idx=18, weight_scale=0.8, tract_scale=1.2):
    W = conn.weights.copy()
    D = conn.tract_lengths.copy()
    W[node_idx, :] *= weight_scale
    W[:, node_idx] *= weight_scale
    D[node_idx, :] *= tract_scale
    D[:, node_idx] *= tract_scale
    conn_lesion = connectivity.Connectivity(weights=W, tract_lengths=D,
                           region_labels=conn.region_labels,
                           centres=conn.centres, speed=conn.speed.copy())
    conn_lesion.configure()
    return conn_lesion

# %%
def damp_node_dynamics(wc_model, node_idx=18, num_regions=76, P_reduction=0.85, c_ie_increase=1.05):
    for pname in ('P', 'c_ie'):
        val = getattr(wc_model, pname)
        if val.size == 1:
            setattr(wc_model, pname, np.repeat(val[0], num_regions))
    wc_model.P[node_idx]    *= P_reduction
    wc_model.c_ie[node_idx] *= c_ie_increase

# %%
def apply_tdcs_effect(wc_model, node_idx=18, P_boost_factor=1.18, c_ie_reduction_factor=1/1.05):
    for pname in ('P', 'c_ie'):
        val = getattr(wc_model, pname)
        if val.size == 1:
            setattr(wc_model, pname, np.repeat(val[0], 76))
    wc_model.P[node_idx] *= P_boost_factor
    wc_model.c_ie[node_idx] *= c_ie_reduction_factor

# %%
n_subjects = 50
results = []
output_dir = "tdcs_mildgroup_results"
os.makedirs(output_dir, exist_ok=True)

# %%
for i in range(n_subjects):
    print(f"Running tDCS subject {i+1}...")

    conn = connectivity.Connectivity.from_file("connectivity_76.zip")
    conn.configure()
    conn_lesion = focal_dlpfc_lesion(conn)

    wc = models.WilsonCowan(
        c_ee=np.array([np.random.normal(20.0, 1.0)]),
        c_ei=np.array([np.random.normal(12.0, 0.5)]),
        c_ie=np.array([np.random.normal(18.0, 1.0)]),
        c_ii=np.array([np.random.normal(3.0, 0.3)]),
        P=np.array([np.random.normal(0.45, 0.02)]),
        tau_e=np.array([10.0]),
        tau_i=np.array([25.0]),
    )

    damp_node_dynamics(wc, node_idx=18)
    wc_tdcs = copy.deepcopy(wc)
    apply_tdcs_effect(wc_tdcs, node_idx=18)
    
    sim = Simulator(
        model=wc_tdcs,
        connectivity=conn_lesion,
        coupling=coupling.Scaling(a=np.array([0.003])),
        integrator=integrators.HeunDeterministic(dt=0.1),
        monitors=(monitors.Raw(variables_of_interest=np.array([0]), period=1.0),)
    )
    sim.simulation_length = 15000
    sim.configure()

    try:
        output = sim.run()[0]
        raw_data = np.squeeze(output[1])
        print("Raw data shape:", raw_data.shape)

        if raw_data.ndim == 2 and raw_data.shape[1] == conn_lesion.number_of_regions:
            ts = raw_data[:, 18]
            alpha_power = np.mean(np.abs(np.fft.rfft(ts))**2)

            fc_matrix = np.corrcoef(raw_data.T)
            np.save(os.path.join(output_dir, f"fc_matrix_{i}.npy"), fc_matrix)
            mean_fc = np.mean(fc_matrix[np.triu_indices(fc_matrix.shape[0], k=1)])
        else:
            print(f"Unexpected shape for subject {i+1}. Skipping.")
            alpha_power = np.nan
            mean_fc = np.nan

    except Exception as e:
        print(f"Error for subject {i+1}: {e}")
        alpha_power = np.nan
        mean_fc = np.nan

    results.append({
        "subject_id": f"tdcs_{i+1}",
        "alpha_power_dlpfc": alpha_power,
        "mean_fc_strength": mean_fc
    })
# Out:
# Running tDCS subject 1...
# 2025-05-17 11:24:32,216 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:24:32,245 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:24:32,927 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 2...
# 2025-05-17 11:24:48,819 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:24:48,826 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:24:48,843 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 3...
# 2025-05-17 11:25:05,122 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:25:05,127 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:25:05,140 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 4...
# 2025-05-17 11:25:21,355 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:25:21,360 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:25:21,367 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 5...
# 2025-05-17 11:25:37,490 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:25:37,494 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:25:37,502 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 6...
# 2025-05-17 11:25:53,740 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:25:53,746 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:25:53,762 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 7...
# 2025-05-17 11:26:09,962 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:26:09,968 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:26:09,983 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 8...
# 2025-05-17 11:26:26,528 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:26:26,532 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:26:26,540 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 9...
# 2025-05-17 11:26:43,203 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:26:43,211 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:26:43,222 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 10...
# 2025-05-17 11:26:59,417 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:26:59,425 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:26:59,434 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 11...
# 2025-05-17 11:27:15,972 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:27:15,995 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:27:16,031 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 12...
# 2025-05-17 11:27:31,993 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:27:32,000 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:27:32,008 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 13...
# 2025-05-17 11:27:48,314 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:27:48,319 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:27:48,327 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 14...
# 2025-05-17 11:28:04,530 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:28:04,540 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:28:04,548 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 15...
# 2025-05-17 11:28:20,022 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:28:20,026 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:28:20,033 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 16...
# 2025-05-17 11:28:35,299 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:28:35,302 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:28:35,309 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 17...
# 2025-05-17 11:28:50,724 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:28:50,728 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:28:50,736 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 18...
# 2025-05-17 11:29:06,105 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:29:06,108 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:29:06,116 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 19...
# 2025-05-17 11:29:21,387 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:29:21,391 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:29:21,401 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 20...
# 2025-05-17 11:29:36,722 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:29:36,725 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:29:36,732 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 21...
# 2025-05-17 11:29:51,978 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:29:51,982 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:29:51,992 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 22...
# 2025-05-17 11:30:07,382 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:30:07,386 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:30:07,394 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 23...
# 2025-05-17 11:30:22,840 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:30:22,845 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:30:22,852 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 24...
# 2025-05-17 11:30:38,832 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:30:38,837 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:30:38,849 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 25...
# 2025-05-17 11:30:54,319 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:30:54,324 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:30:54,335 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 26...
# 2025-05-17 11:31:11,104 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:31:11,110 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:31:11,122 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 27...
# 2025-05-17 11:31:26,545 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:31:26,549 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:31:26,556 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 28...
# 2025-05-17 11:31:41,947 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:31:41,950 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:31:41,957 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 29...
# 2025-05-17 11:31:57,487 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:31:57,493 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:31:57,501 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 30...
# 2025-05-17 11:32:12,917 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:32:12,922 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:32:12,930 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 31...
# 2025-05-17 11:32:28,284 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:32:28,289 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:32:28,297 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 32...
# 2025-05-17 11:32:43,528 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:32:43,533 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:32:43,539 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 33...
# 2025-05-17 11:32:58,772 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:32:58,776 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:32:58,782 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 34...
# 2025-05-17 11:33:14,193 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:33:14,197 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:33:14,205 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 35...
# 2025-05-17 11:33:29,491 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:33:29,496 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:33:29,503 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 36...
# 2025-05-17 11:33:44,790 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:33:44,794 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:33:44,804 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 37...
# 2025-05-17 11:34:00,087 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
# ...
# 2025-05-17 11:34:15,489 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 39...
# 2025-05-17 11:34:30,778 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:34:30,782 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:34:30,788 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 40...
# 2025-05-17 11:34:46,046 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:34:46,051 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:34:46,059 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 41...
# 2025-05-17 11:35:01,810 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:35:01,815 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:35:01,823 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 42...
# 2025-05-17 11:35:17,286 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:35:17,290 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:35:17,298 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 43...
# 2025-05-17 11:35:32,728 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:35:32,733 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:35:32,741 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 44...
# 2025-05-17 11:35:48,149 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:35:48,153 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:35:48,161 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 45...
# 2025-05-17 11:36:03,482 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:36:03,484 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:36:03,492 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 46...
# 2025-05-17 11:36:18,899 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:36:18,904 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:36:18,917 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 47...
# 2025-05-17 11:36:34,213 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:36:34,216 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:36:34,238 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 48...
# 2025-05-17 11:36:49,613 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:36:49,618 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:36:49,626 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 49...
# 2025-05-17 11:37:05,609 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:37:05,619 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:37:05,634 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 50...
# 2025-05-17 11:37:21,290 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-17 11:37:21,294 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-17 11:37:21,302 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)

# %%
df = pd.DataFrame(results)
df.to_csv(os.path.join(output_dir, "tdcs_mildgroup_metrics.csv"), index=False)
print("All tDCS simulations completed. Results saved to:", output_dir)
# Out:
# All tDCS simulations completed. Results saved to: tdcs_mildgroup_results
