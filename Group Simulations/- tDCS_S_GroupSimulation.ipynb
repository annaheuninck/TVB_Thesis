# %%
import numpy as np
import pandas as pd
import os
import copy
from tvb.simulator.lab import models, connectivity, coupling, integrators, monitors
from tvb.simulator.simulator import Simulator
# Out:
# /opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/datatypes/surfaces.py:60: UserWarning: Geodesic distance module is unavailable; some functionality for surfaces will be unavailable.
#   warnings.warn(msg)

# %%
np.random.seed(50)

# %%
def focal_dlpfc_lesion(conn, node_idx=18, weight_scale=0.3, tract_scale=1.5):
    W = conn.weights.copy()
    D = conn.tract_lengths.copy()
    W[node_idx, :] *= weight_scale
    W[:, node_idx] *= weight_scale
    D[node_idx, :] *= tract_scale
    D[:, node_idx] *= tract_scale
    conn_lesion = connectivity.Connectivity(weights=W, tract_lengths=D,
                           region_labels=conn.region_labels,
                           centres=conn.centres, speed=conn.speed.copy())
    conn_lesion.configure()
    return conn_lesion

# %%
def damp_node_dynamics(wc_model, node_idx=18, num_regions=76, P_reduction=0.5, c_ie_increase=1.2):
    for pname in ('P', 'c_ie'):
        val = getattr(wc_model, pname)
        if val.size == 1:
            setattr(wc_model, pname, np.repeat(val[0], num_regions))
    wc_model.P[node_idx]    *= P_reduction
    wc_model.c_ie[node_idx] *= c_ie_increase

# %%
def apply_tdcs_effect(wc_model, node_idx=18, P_boost_factor=2.0, c_ie_reduction_factor=1/1.2):
    for pname in ('P', 'c_ie'):
        val = getattr(wc_model, pname)
        if val.size == 1:
            setattr(wc_model, pname, np.repeat(val[0], 76))
    wc_model.P[node_idx] *= P_boost_factor
    wc_model.c_ie[node_idx] *= c_ie_reduction_factor

# %%
n_subjects = 50
results = []
output_dir = "tdcs_stronggroup_results"
os.makedirs(output_dir, exist_ok=True)

# %%
for i in range(n_subjects):
    print(f"Running tDCS subject {i+1}...")

    conn = connectivity.Connectivity.from_file("connectivity_76.zip")
    conn.configure()
    conn_lesion = focal_dlpfc_lesion(conn)

    wc = models.WilsonCowan(
        c_ee=np.array([np.random.normal(20.0, 1.0)]),
        c_ei=np.array([np.random.normal(12.0, 0.5)]),
        c_ie=np.array([np.random.normal(18.0, 1.0)]),
        c_ii=np.array([np.random.normal(3.0, 0.3)]),
        P=np.array([np.random.normal(0.45, 0.02)]),
        tau_e=np.array([10.0]),
        tau_i=np.array([25.0]),
    )

    damp_node_dynamics(wc, node_idx=18)
    wc_tdcs = copy.deepcopy(wc)
    apply_tdcs_effect(wc_tdcs, node_idx=18)
    
    sim = Simulator(
        model=wc_tdcs,
        connectivity=conn_lesion,
        coupling=coupling.Scaling(a=np.array([0.003])),
        integrator=integrators.HeunDeterministic(dt=0.1),
        monitors=(monitors.Raw(variables_of_interest=np.array([0]), period=1.0),)
    )
    sim.simulation_length = 15000
    sim.configure()

    try:
        output = sim.run()[0]
        raw_data = np.squeeze(output[1])
        print("Raw data shape:", raw_data.shape)

        if raw_data.ndim == 2 and raw_data.shape[1] == conn_lesion.number_of_regions:
            ts = raw_data[:, 18]
            alpha_power = np.mean(np.abs(np.fft.rfft(ts))**2)

            fc_matrix = np.corrcoef(raw_data.T)
            np.save(os.path.join(output_dir, f"fc_matrix_{i}.npy"), fc_matrix)
            mean_fc = np.mean(fc_matrix[np.triu_indices(fc_matrix.shape[0], k=1)])
        else:
            print(f"Unexpected shape for subject {i+1}. Skipping.")
            alpha_power = np.nan
            mean_fc = np.nan

    except Exception as e:
        print(f"Error for subject {i+1}: {e}")
        alpha_power = np.nan
        mean_fc = np.nan

    results.append({
        "subject_id": f"tdcs_{i+1}",
        "alpha_power_dlpfc": alpha_power,
        "mean_fc_strength": mean_fc
    })
# Out:
# Running tDCS subject 1...
# 2025-05-15 10:54:44,582 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:54:44,609 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:54:45,186 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 2...
# 2025-05-15 10:55:01,025 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:55:01,045 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:55:01,064 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 3...
# 2025-05-15 10:55:16,146 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:55:16,151 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:55:16,159 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 4...
# 2025-05-15 10:55:31,453 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:55:31,457 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:55:31,467 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 5...
# 2025-05-15 10:55:46,861 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:55:46,867 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:55:46,879 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 6...
# 2025-05-15 10:56:02,167 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:56:02,172 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:56:02,180 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 7...
# 2025-05-15 10:56:17,091 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:56:17,095 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:56:17,104 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 8...
# 2025-05-15 10:56:32,199 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:56:32,209 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:56:32,217 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 9...
# 2025-05-15 10:56:47,142 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:56:47,146 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:56:47,152 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 10...
# 2025-05-15 10:57:02,463 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:57:02,467 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:57:02,484 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 11...
# 2025-05-15 10:57:18,641 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:57:18,647 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:57:18,658 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 12...
# 2025-05-15 10:57:34,039 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:57:34,044 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:57:34,052 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 13...
# 2025-05-15 10:57:49,866 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:57:49,870 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:57:49,888 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 14...
# 2025-05-15 10:58:05,376 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:58:05,384 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:58:05,396 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 15...
# 2025-05-15 10:58:20,588 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:58:20,593 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:58:20,601 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 16...
# 2025-05-15 10:58:35,533 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:58:35,536 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:58:35,543 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 17...
# 2025-05-15 10:58:50,513 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:58:50,517 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:58:50,523 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 18...
# 2025-05-15 10:59:05,630 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:59:05,635 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:59:05,642 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 19...
# 2025-05-15 10:59:20,816 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:59:20,820 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:59:20,828 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 20...
# 2025-05-15 10:59:36,623 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:59:36,630 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:59:36,640 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 21...
# 2025-05-15 10:59:51,701 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:59:51,706 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 10:59:51,713 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 22...
# 2025-05-15 11:00:06,727 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:00:06,730 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:00:06,737 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 23...
# 2025-05-15 11:00:21,871 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:00:21,875 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:00:21,890 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 24...
# 2025-05-15 11:00:37,025 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:00:37,030 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:00:37,038 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 25...
# 2025-05-15 11:00:52,093 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:00:52,098 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:00:52,105 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 26...
# 2025-05-15 11:01:07,500 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:01:07,505 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:01:07,514 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 27...
# 2025-05-15 11:01:22,855 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:01:22,860 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:01:22,867 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 28...
# 2025-05-15 11:01:37,910 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:01:37,914 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:01:37,923 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 29...
# 2025-05-15 11:01:53,000 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:01:53,008 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:01:53,022 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 30...
# 2025-05-15 11:02:08,029 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:02:08,039 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:02:08,046 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 31...
# 2025-05-15 11:02:23,191 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:02:23,197 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:02:23,206 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 32...
# 2025-05-15 11:02:38,433 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:02:38,438 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:02:38,446 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 33...
# 2025-05-15 11:02:53,442 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:02:53,446 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:02:53,455 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 34...
# 2025-05-15 11:03:08,517 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:03:08,521 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:03:08,528 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 35...
# 2025-05-15 11:03:23,674 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:03:23,678 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:03:23,685 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 36...
# 2025-05-15 11:03:38,633 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:03:38,637 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:03:38,655 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 37...
# 2025-05-15 11:03:53,730 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
# ...
# 2025-05-15 11:04:09,112 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 39...
# 2025-05-15 11:04:24,324 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:04:24,328 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:04:24,336 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 40...
# 2025-05-15 11:04:39,480 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:04:39,485 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:04:39,496 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 41...
# 2025-05-15 11:04:54,526 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:04:54,531 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:04:54,538 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 42...
# 2025-05-15 11:05:09,540 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:05:09,544 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:05:09,551 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 43...
# 2025-05-15 11:05:24,759 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:05:24,764 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:05:24,771 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 44...
# 2025-05-15 11:05:39,922 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:05:39,938 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:05:39,956 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 45...
# 2025-05-15 11:05:55,011 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:05:55,015 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:05:55,023 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 46...
# 2025-05-15 11:06:10,121 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:06:10,127 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:06:10,141 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 47...
# 2025-05-15 11:06:25,193 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:06:25,204 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:06:25,216 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 48...
# 2025-05-15 11:06:40,302 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:06:40,307 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:06:40,314 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 49...
# 2025-05-15 11:06:55,303 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:06:55,306 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:06:55,312 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)
# Running tDCS subject 50...
# 2025-05-15 11:07:10,310 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 11:07:10,314 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2025-05-15 11:07:10,322 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration
# Raw data shape: (150000, 76)

# %%
df = pd.DataFrame(results)
df.to_csv(os.path.join(output_dir, "tdcs_group_metrics.csv"), index=False)
print("All tDCS simulations completed. Results saved to:", output_dir)
# Out:
# All tDCS simulations completed. Results saved to: tdcs_stronggroup_results
