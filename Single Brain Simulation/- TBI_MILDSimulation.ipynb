# %%
from tvb.simulator.lab import *
from tvb.datatypes.connectivity import Connectivity
import numpy as np
import matplotlib.pyplot as plt

# %%
conn = Connectivity.from_file("connectivity_76.zip")
conn.configure()
N = conn.number_of_regions
# Out:
# 2025-05-15 10:03:57,929 - ERROR - tvb.basic.readers - Could not import tvb_data Python module for default data-set!
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/site-packages/tvb/basic/readers.py", line 222, in try_get_absolute_path
#     module_import = importlib.import_module(relative_module)
#   File "/opt/anaconda3/envs/tvb_env/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tvb_data'
# 2025-05-15 10:03:58,011 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.

# %%
wc = models.WilsonCowan(
    c_ee=np.array([20.0]),           
    c_ei=np.array([12.0]),
    c_ie=np.array([18.0]),
    c_ii=np.array([3.0]),
    P   =np.array([0.45]),           
    tau_e=np.array([10.0]),
    tau_i=np.array([25.0]),
)

# %%
cpl = coupling.Linear(a=np.array([0.015]))
heun = integrators.HeunDeterministic(dt=0.1)
heun.noise = noise.Additive(nsig=np.array([0.02, 0.02]))

ic = np.zeros((1, 2, N, 1))
ic[0,0,:] = 0.3
ic[0,1,:] = 0.0

# %%
def focal_strong_dlpfc_lesion(conn, node_idx=18, weight_scale=0.8, tract_scale=1.2):
    W = conn.weights.copy()
    D = conn.tract_lengths.copy()
    W[node_idx, :] *= weight_scale
    W[:, node_idx] *= weight_scale
    D[node_idx, :] *= tract_scale
    D[:, node_idx] *= tract_scale
    conn_lesion = Connectivity(weights=W, tract_lengths=D,
                               region_labels=conn.region_labels,
                               centres=conn.centres, speed=conn.speed.copy())
    conn_lesion.configure()
    return conn_lesion

def damp_node_dynamics(wc_model, node_idx=18, num_regions=76,
                       P_reduction=0.85, c_ie_increase=1.05):
    """
    Modifies a Wilson-Cowan model object *in place* to damp activity at one node.
    """
    for pname in ('P', 'c_ie'):
        val = getattr(wc_model, pname)
        if val.size == 1:
            setattr(wc_model, pname, np.repeat(val[0], num_regions))
    wc_model.P[node_idx]    *= P_reduction
    wc_model.c_ie[node_idx] *= c_ie_increase

# %%
raw_mon = monitors.Raw()
bold_mon = monitors.Bold(period=2000.0)

# %%
TBI_conn = focal_strong_dlpfc_lesion(conn, node_idx=18, weight_scale=0.8, tract_scale=1.2)

import copy
wc_lesion = copy.deepcopy(wc)

damp_node_dynamics(wc_lesion, node_idx=18,
                   num_regions=TBI_conn.number_of_regions,
                   P_reduction=0.85, c_ie_increase=1.05)

heun.noise = noise.Additive(nsig=np.array([0.05, 0.05]))

# %%
sim_TBI = simulator.Simulator(
    model=wc_lesion,
    connectivity=TBI_conn,
    coupling=cpl,
    integrator=heun,  
    monitors=[raw_mon, bold_mon]
)
sim_TBI.simulation_length = 600000.0  
sim_TBI.initial_conditions = ic
sim_TBI.configure()
# Out:
# <table>
# <thead><h3>Simulator</h3></thead>
# <tbody>
# <tr><td colspan="2"><p><div class="document" id="2a1c4872-3163-11f0-a20c-badf7d8385ab">
# <p>A Simulator assembles components required to perform simulations.</p>
# </div>
# <script>MathJax.Hub.Queue(["Typeset", MathJax.Hub, "2a1c4872-3163-11f0-a20c-badf7d8385ab"]);</script></p></td></tr>
# <tr><th></th><th style="text-align:left;width:80%">value</th></tr>
# <tr><td>Type</td><td style="text-align:left;"><pre>Simulator</pre></td></tr>
# <tr><td>conduction_speed</td><td style="text-align:left;"><pre>3.0</pre></td></tr>
# <tr><td>connectivity</td><td style="text-align:left;"><pre>Connectivity gid: e3b9b8a6-9e52-4d19-a5e6-92b1d823243d</pre></td></tr>
# <tr><td>coupling</td><td style="text-align:left;"><pre>Linear gid: b9bfd3db-31fa-4637-9c7a-4abbf909b094</pre></td></tr>
# <tr><td>gid</td><td style="text-align:left;"><pre>UUID('dcfd7fbf-4265-444f-abab-95103e6fc2c8')</pre></td></tr>
# <tr><td>initial_conditions</td><td style="text-align:left;"><pre> [min, median, max] = [0, 0.15, 0.3] dtype = float64 shape = (1, 2, 76, 1)</pre></td></tr>
# <tr><td>integrator</td><td style="text-align:left;"><pre>HeunDeterministic gid: d7151395-c75d-4da6-82a0-e72cad68842f</pre></td></tr>
# <tr><td>model</td><td style="text-align:left;"><pre>WilsonCowan gid: a0cdd061-5823-407d-9ea6-c19f2a6cbfce</pre></td></tr>
# <tr><td>monitors</td><td style="text-align:left;"><pre>[<tvb.simulator.monitors.Raw object at 0x1642b4a90>, <tvb.simulator.monitors.Bold object at 0x1642b4b80>]</pre></td></tr>
# <tr><td>simulation_length</td><td style="text-align:left;"><pre>600000.0</pre></td></tr>
# <tr><td>stimulus</td><td style="text-align:left;"><pre>None</pre></td></tr>
# <tr><td>surface</td><td style="text-align:left;"><pre>None</pre></td></tr>
# <tr><td>title</td><td style="text-align:left;"><pre>Simulator gid: dcfd7fbf-4265-444f-abab-95103e6fc2c8</pre></td></tr>
# </tbody></table>

# %%
result = sim_TBI.run()
(raw_t, raw_dat) = result[0]
(bold_t, bold_dat) = result[1]
# Out:
# 2025-05-15 10:04:03,985 - WARNING - tvb.simulator.integrators - random_state supplied for non-stochastic integration

# %%
bold_time_sec = bold_t / 1000  
bold_signal = bold_dat[:, 0, 18, 0]

# %%
discard_time = 7
discard_index = np.where(bold_time_sec >= discard_time)[0][0]

# %%
bold_time_trimmed = bold_time_sec[discard_index:]
bold_signal_trimmed = bold_signal[discard_index:]

# %%
plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
plt.plot(raw_t/1000, raw_dat[:,0,18,0], lw=1)
plt.title("Raw Wilson–Cowan Excitatory Activity – Region 18 (DLPFC)")
plt.ylabel("E activity"); plt.grid(True)

plt.subplot(2,1,2)
plt.plot(bold_time_trimmed, bold_signal_trimmed, lw=1.2)
plt.title("Simulated BOLD Signal – Region 18 (DLPFC)")
plt.xlabel("Time (s)"); plt.ylabel("BOLD amplitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("figures/tbi_mild_signals.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
time = raw_t
data = raw_dat[:, 0, :, 0]
print(f"Time shape: {time.shape}, Data shape: {data.shape}")
# Out:
# Time shape: (6000000,), Data shape: (6000000, 76)

# %%
selected_regions = [18, 23, 51, 74]

# %%
start_time = 100000  
end_time = 105000

# %%
start_idx = (time >= start_time).argmax()
end_idx = (time >= end_time).argmax()

# %%
plt.figure(figsize=(10, 6))
for region in selected_regions:
    plt.plot(time[start_idx:end_idx], data[start_idx:end_idx, region], label=f'Region {region}')
plt.title('Simulated Brain Activity - TBI MILD Brain (Zoomed In)')
plt.xlabel('Time (ms)')
plt.ylabel('Neural Activity (a.u.)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("figures/tbi_mild_zoomed_regions.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
bold_signals = bold_dat[:, 0, :, 0]

# %%
bold_time_sec = bold_t / 1000
discard_idx = np.where(bold_time_sec >= 7)[0][0]
bold_signals = bold_signals[discard_idx:, :]

# %%
fc_matrix = np.corrcoef(bold_signals.T)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(fc_matrix, cmap='bwr', vmin=-1, vmax=1)
plt.colorbar(label='Pearson r')
plt.title('Functional Connectivity Matrix (TBI Mild)')
plt.xlabel('Region')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %%
np.save("fc_matrix_tbimild.npy", fc_matrix)
